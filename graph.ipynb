# %% [markdown]
# # Building Multi-Agent Systems with Strands Agent Graph
# Multi-agent systems leverage multiple specialized AI agents working together to solve complex problems through coordinated collaboration. Each agent has specific capabilities and roles, connected through explicit communication pathways.
#
# In this lab, you'll learn to build multi-agent systems using the Strands Agent SDK. We'll progress from basic concepts to advanced implementations, exploring different topologies and real-world applications.
#
# **Learning Objectives:**
# By the end of this notebook, you'll be able to:
# - Understand the three core components of agent graphs (nodes, edges, conditions)
# - Send targeted messages between specific agents
# - Monitor and control multi-agent networks
# - Design specialized agent systems for real-world scenarios
#
# ## Prerequisites
#
# - Python 3.10+
# - AWS account with Anthropic Claude 3.7 enabled on Amazon Bedrock
# - IAM role with permissions to use Amazon Bedrock
# - Basic understanding of AI agents and prompt engineering

# %% [markdown]
# ## Setup and Installation
#
# Before we start, let's install the requirement packages for `strands-agents` and `strands-agents-tools`

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Importing required packages
#
# Next we can import the required packages

# %%
from strands import Agent

# %% [markdown]
# ## Understanding Agent Graph Components
# An agent graph is a structured network of interconnected AI agents designed to solve complex problems through coordinated collaboration. Each agent represents a specialized node with specific capabilities, and the connections between agents define explicit communication pathways.
#
# Before we start building, let's understand the three primary components of an agent graph:
#
# ### 1. Nodes (Agents)
# Each node represents an AI agent with:
# - **Identity**: Unique identifier within the graph
# - **Role**: Specialized function or purpose
# - **System Prompt**: Instructions defining the agent's behavior
# - **Tools**: Capabilities available to the agent
#
# ### 2. Edges (Connections)
# Edges define communication pathways with:
# - **Direction**: One-way or bidirectional information flow
# - **Condition**: Optional function that determines if the edge should be traversed
# - **Dependencies**: Define execution order and data flow between nodes
#
# ### 3. GraphBuilder
# The GraphBuilder provides a simple interface for constructing graphs:
# - **add_node()**: Add an agent or multi-agent system as a node
# - **add_edge()**: Create a dependency between nodes
# - **set_entry_point()**: Define starting nodes for execution
# - **build()**: Validate and create the Graph instance

# %% [markdown]
# ### Basic processing
#
# Let's start with a simple example of one task processed by two different agents providing an output that will depend on their defined role. Take a look at the execution order of the nodes and also the fact that with STrands SDK you can explicitly get a response only from one single node if needed. Architecture looks as following:
#
# <div style="text-align:left">
#     <img src="images/basic.png" width="55%" />
# </div>

# %%
# Setup AWS Bedrock configuration
import boto3
import os
from strands import Agent, tool
from strands_tools import calculator

# Configure AWS region for Bedrock
AWS_REGION = "us-east-1"  # Claude 3.7 Sonnet is available in us-east-1
CLAUDE_MODEL_ID = "us.anthropic.claude-3-7-sonnet-20250219-v1:0"


# Verify AWS credentials are configured
try:
    session = boto3.Session()
    credentials = session.get_credentials()
    if credentials is None:
        print("⚠️  AWS credentials not found. Please configure your AWS credentials.")
        print("   You can use: aws configure")
        print("   Or set environment variables: AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY")
    else:
        print("✓ AWS credentials configured")
        
    # Test Bedrock access
    bedrock = boto3.client('bedrock', region_name=AWS_REGION)
    print("✓ Amazon Bedrock client initialized")
    
except Exception as e:
    print(f"✗ Error setting up AWS: {e}")
    print("Please ensure you have proper AWS credentials and permissions for Bedrock.")
# Out:
# ✓ AWS credentials configured
# ✓ Amazon Bedrock client initialized

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

# Create specialized agents
coordinator = Agent(model=CLAUDE_MODEL_ID, name="coordinator", system_prompt="You are a research team leader coordinating specialists. Provide a short analysis, no need for follow ups")
analyst = Agent(model=CLAUDE_MODEL_ID, name="data_analyst", system_prompt="You are a data analyst specializing in statistical analysis. Provide a short analysis, no need for follow ups")
domain_expert = Agent(model=CLAUDE_MODEL_ID, name="domain_expert", system_prompt="You are a domain expert with deep subject knowledge. Provide a short analysis, no need for follow ups")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(coordinator, "team_lead")
builder.add_node(analyst, "analyst")
builder.add_node(domain_expert, "expert")

# Add edges (dependencies)
builder.add_edge("team_lead", "analyst")
builder.add_edge("team_lead", "expert")

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("team_lead")

# Build the graph
graph = builder.build()

#Execute task on newly built graph
result = graph("Analyze the impact of remote work on employee productivity.Provide a short analysis, no need for follow ups")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes
print("\n")
print("=============Expert node results only:======================")
print("============================================================")
print(result.results["expert"].result)
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# # Impact of Remote Work on Employee Productivity
#
# Our research synthesis indicates mixed but generally positive impacts on productivity:
#
# **Key Findings:**
# - Productivity increases of 13-22% reported across multiple studies, primarily due to reduced commute time and fewer workplace distractions
# - Task-dependent outcomes: creative collaboration often suffers while focused individual work benefits
# - Employee well-being shows improvement through better work-life balance, though isolation concerns exist
# - Technology infrastructure quality and home workspace environment significantly moderate productivity outcomes
# - Self-reported productivity gains may not always align with objective measures
#
# The data suggests organizations should consider hybrid models tailored to job functions rather than one-size-fits-all remote work policies.## Analysis of Remote Work's Brief Statistical Analysis: Impact on Employee Productivity
#
# Based on the research synthesis provided, remote Remote Work's Impact on Employee Productivity work shows
#
# Based on the provided synthesis, the statistical evidence a nuanced but generally positive effect shows a productivity increase range of 13-22% for remote on employee productivity. The reporte workers, representingd productivity increases of 13-22 a significant% appear significant an positive effect. These findings exhibitd stem primarily from eliminated commute times classic characteristics and fewer office distractions. of moderating variables, where However, this impact varies considerably benefits aren't universal but depend on:
#
# 1. Task type (individual focus work vs. collaborative by task type - creative tasks) individual focused work benefits while collaborative creative endeavors may suffer.
#
# The productivity gains appear to be
# 2. Infrastructure quality (technological moderated by two critical factors: technology capabilities)
# 3. Work infrastructure quality and home environment factors (home workspace environments. This suggests that organizations looking to maximize setup adequacy)
#
# The reported productivity gains demonstrate remote work benefits should invest in both proper a potential measurement bias between self-reported and objective productivity technological tools metrics, suggesting caution in and guidance interpretation. The for optimal home office setups.
#
# The research also data supports a differentiated approach to remote work policies rather than blanket implementation indicates a connection between employee well-being through, as productivity impacts show better work-life balance and productivity outcomes statistical heterogeneity across, though isolation remains job functions and working conditions a concern. The disconnect. between self-reported productivity and objective measures warrants careful consideration when evaluating remote work effectiveness.
#
# This evidence points toward hybrid work models customized to specific job functions as potentially the most effective approach for organizations.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'team_lead': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Impact of Remote Work on Employee Productivity\n\nOur research synthesis indicates mixed but generally positive impacts on productivity:\n\n**Key Findings:**\n- Productivity increases of 13-22% reported across multiple studies, primarily due to reduced commute time and fewer workplace distractions\n- Task-dependent outcomes: creative collaboration often suffers while focused individual work benefits\n- Employee well-being shows improvement through better work-life balance, though isolation concerns exist\n- Technology infrastructure quality and home workspace environment significantly moderate productivity outcomes\n- Self-reported productivity gains may not always align with objective measures\n\nThe data suggests organizations should consider hybrid models tailored to job functions rather than one-size-fits-all remote work policies.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[9.986308813095093], traces=[<strands.telemetry.metrics.Trace object at 0x10f9ebe90>], accumulated_usage={'inputTokens': 50, 'outputTokens': 150, 'totalTokens': 200}, accumulated_metrics={'latencyMs': 8805}), state={}), execution_time=9987, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 50, 'outputTokens': 150, 'totalTokens': 200}, accumulated_metrics={'latencyMs': 8805}, execution_count=1), 'analyst': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Brief Statistical Analysis: Remote Work's Impact on Employee Productivity\n\nBased on the provided synthesis, the statistical evidence shows a productivity increase range of 13-22% for remote workers, representing a significant positive effect. These findings exhibit classic characteristics of moderating variables, where benefits aren't universal but depend on:\n\n1. Task type (individual focus work vs. collaborative creative tasks)\n2. Infrastructure quality (technological capabilities)\n3. Work environment factors (home setup adequacy)\n\nThe reported productivity gains demonstrate a potential measurement bias between self-reported and objective productivity metrics, suggesting caution in interpretation. The data supports a differentiated approach to remote work policies rather than blanket implementation, as productivity impacts show statistical heterogeneity across job functions and working conditions."}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.937455892562866], traces=[<strands.telemetry.metrics.Trace object at 0x10f9fbf90>], accumulated_usage={'inputTokens': 218, 'outputTokens': 160, 'totalTokens': 378}, accumulated_metrics={'latencyMs': 4657}), state={}), execution_time=5938, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 218, 'outputTokens': 160, 'totalTokens': 378}, accumulated_metrics={'latencyMs': 4657}, execution_count=1), 'expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Analysis of Remote Work's Impact on Employee Productivity\n\nBased on the research synthesis provided, remote work shows a nuanced but generally positive effect on employee productivity. The reported productivity increases of 13-22% appear significant and stem primarily from eliminated commute times and fewer office distractions. However, this impact varies considerably by task type - individual focused work benefits while collaborative creative endeavors may suffer.\n\nThe productivity gains appear to be moderated by two critical factors: technology infrastructure quality and home workspace environments. This suggests that organizations looking to maximize remote work benefits should invest in both proper technological tools and guidance for optimal home office setups.\n\nThe research also  ...
# =============Node execution order:==========================
# ============================================================
# Executed: team_lead
# Executed: analyst
# Executed: expert
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 3
# Failed nodes: 0
# Execution time: 17051ms
# Token usage: {'inputTokens': 485, 'outputTokens': 515, 'totalTokens': 1000}
#
#
# =============Expert node results only:======================
# ============================================================
# # Analysis of Remote Work's Impact on Employee Productivity
#
# Based on the research synthesis provided, remote work shows a nuanced but generally positive effect on employee productivity. The reported productivity increases of 13-22% appear significant and stem primarily from eliminated commute times and fewer office distractions. However, this impact varies considerably by task type - individual focused work benefits while collaborative creative endeavors may suffer.
#
# The productivity gains appear to be moderated by two critical factors: technology infrastructure quality and home workspace environments. This suggests that organizations looking to maximize remote work benefits should invest in both proper technological tools and guidance for optimal home office setups.
#
# The research also indicates a connection between employee well-being through better work-life balance and productivity outcomes, though isolation remains a concern. The disconnect between self-reported productivity and objective measures warrants careful consideration when evaluating remote work effectiveness.
#
# This evidence points toward hybrid work models customized to specific job functions as potentially the most effective approach for organizations.

# %% [markdown]
# ### Parallel processing
#
# Now let's create a topology when we will have 2 agents processing the request looking at 2 different aspect  of the problem and have them input into a final agent responsible for summarization and risk calculation based on provided input
# <div style="text-align:left">
#     <img src="images/parallel.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

financial_advisor = Agent(model=CLAUDE_MODEL_ID, name="financial_advisor", system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Engage with other experts to build comprehensive financial perspectives.")
technical_architect = Agent(model=CLAUDE_MODEL_ID, name="technical_architect", system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Collaborate with other experts to ensure technical viability.")
market_researcher = Agent(model=CLAUDE_MODEL_ID, name="market_researcher", system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Work with other experts to validate market opportunities.")
risk_analyst = Agent(model=CLAUDE_MODEL_ID, name="risk_analyst", system_prompt="You are a risk analyst who identifies potential risks, mitigation strategies, and compliance issues. Collaborate with other experts to ensure comprehensive risk assessment.")


# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges (dependencies)
builder.add_edge("finance_expert", "tech_expert")
builder.add_edge("finance_expert", "market_expert")
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")


# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("finance_expert")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Our company is considering launching a new AI-powered customer service platform. Initial investment is \$2M with projected 3-year ROI of 150%. What's your financial assessment?")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes

print("Financial Advisor:")
print("============================================================")
print("============================================================")
print(result.results["finance_expert"].result)
print("\n")

print("Technical Expert:")
print("============================================================")
print("============================================================")
print(result.results["tech_expert"].result)
print("\n")

print("Market Researcher:")
print("============================================================")
print("============================================================")
print(result.results["market_expert"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# # Financial Assessment: AI-Powered Customer Service Platform
#
# From a financial perspective, this investment presents an attractive opportunity, but I'd recommend further analysis before proceeding.
#
# ## Initial Analysis
# - $2M upfront investment
# - 150% projected 3-year ROI implies a $5M return ($3M profit) over the period
# - Simple annual return would average approximately 50% (very strong)
#
# ## Key Financial Considerations
# - **Cash Flow Timing**: When will returns begin materializing? Is the ROI back-loaded?
# - **Budget Impact**: How does this affect short-term liquidity and other planned investments?
# - **ROI Calculation Verification**: Were all costs factored in? (ongoing maintenance, training, integration)
# - **Sensitivity Analysis**: How robust is the ROI if adoption is slower or implementation costs increase?
#
# ## Recommended Next Steps
# 1. Request detailed quarterly cash flow projections
# 2. Compare against alternative investments/opportunities
# 3. Establish clear financial KPIs for measuring actual performance against projections
#
# Would you like me to explore any specific aspect of this investment in greater detail?# Technical Architecture# Assessment: AI-Powered Customer Service Platform Market Research Assessment
#
# ## Technical: AI-Powered Customer Service Platform
#
# ## Feasibility Overview Market
# The propose Landscape Analysisd AI-powered customer service platform appears
#
# Base technically viabled on the financial proj based on current AIections ($2M investment capabilities, though successful implementation will depen with 150% 3-year ROd on several keyI), I architectural've considerations.
#
# ## conducted a market assessment to validate Critical Technical Considerations these expectations against current
#
# ### Integration Requirements
# - ** market conditions.
#
# ### MarketExisting Systems Integration**: Will Trends
# - The AI customer service market is growing at require robust API development to 25-30% annually, indicating strong demand connect with CRM, knowledge bases, tick
# - Enterpriseeting systems, an adoption of AI for customer service hasd communication channels increased by 45
# - **Data% in the last two years
# - Migration Strategy**: Need for Competitor solutions are showing clean 30- data transfer40 from legacy% reduction in customer service costs systems without service for disruptions clients
#
# ### Customer
#
# ### Technical Needs Architecture Validation Decisions
# - Primary
# - **Build vs. Buy Assessment customer pain points include:
#   **: Evaluate developing- Rising support proprietary AI costs ( modelsparticularly versus leveraging existing solutions staffing)
#   - Increasing customer expectations for  (e.g., Azure Bot24/7  Service, Googleimmediate support
#   - Dialogflow, IBM Difficulty scaling human support teams during peak periods Watson)
# - **Cloud vs. On-Premise
#
# ### Competitive**: Trade Analysis
# - Market has-offs between control both, security established players requirements an, and scalabilityd new entrants
# - Key needs
# - **Real-time Processing differentiators driving success include integration Capabilities**: Architecture capabilities, accuracy of AI responses, and implementation must support sub-second response times for customer tim interactionselines
# - Price points range from $50K-500K annually
#
# ### Implementation Challenges
# - **AI Model Training depending on scale and features
#
# ## Financial Projection Assessment**: Will require substantial domain-specific data;
# - The insufficient training data will impact service 150% RO qualityI appears achiev
# - **Scalabilityable but Design depends**: Must handle variable load patterns heavily on:
#   1. Competitive differentiation strategy
#   2. with minimal Sales latency cycle length
# - **Security ( Architecturetypically 3-9**: Need for comprehensive months in this data protection, particularly sector)
#   3. Customer for customer information acquisition costs (currently
#
# ## Risk averaging Assessment 15
# --20% of **Technical first Debt-year revenue)
#
# ## Recommendations
# 1**: Rushe. Conduct customerd implementation to meet RO interviewsI timelines could create with long -term maintenance3-5 potential early adopters to validate issues
# - ** pricingVendor Lock-in model
# 2.**: Depending on platform choices, potential Perform competitive feature for dependency gap on specific analysis before vendors
# - ** finalizing development roaSkill Requirements**: Teamdmap
# 3. capabilities assessment Consider a neede phased rolloutd for AI model strategy maintenance to reduce initial and platform investment evolution risk
#
# Would you like me to
#
# ## Recommendations explore any specific market segment
# 1. Conduct or customer needs in technical greater detail? discovery phase to map integration points and data requirements
# 2. Develop proof-of-concept with subset of functionality to validate technical approach
# 3. Include 15-20% contingency in technical implementation budget for unforeseen challenges
#
# The projected ROI appears achievable from a technical perspective, assuming proper architectural planning and execution.# Risk Analysis Assessment: AI-Powered Customer Service Platform
#
# ## Executive Risk Summary
# Based on the technical and market expert inputs, the proposed AI customer service platform presents a moderate risk profile with the $2M investment and 150% 3-year ROI projection. While technically feasible and aligned with market trends, several significant risk factors require mitigation strategies.
#
# ## Key Risk Factors
#
# ### Compliance & Regulatory Risks
# - **Data Privacy Concerns**: AI systems processing customer data must comply with GDPR, CCPA, and industry-specific regulations
# - **AI Governance Issues**: Emerging regulations around AI transparency and decision-making may impact implementation
# - **Cross-border Data Transfers**: International deployments face complex regulatory requirements
#
# ### Operational Risks
# - **Service Continuity**: Transition period from existing systems presents potential service disruption
# - **Dependency on Quality Training Data**: Insufficient or biased training data could lead to poor customer experiences
# - **Staffing/Skills Gap**: Technical debt may accumulate if internal teams lack AI maintenance capabilities
#
# ### Financial Risks
# - **Implementation Cost Overruns**: Technical complexities frequently lead to budget extensions (recommend 20% contingency)
# - **Extended Sales Cycles**: As noted by market expert, 3-9 month sales cycles may delay revenue realization
# - **Vendor/Partner Dependencies**: Lock-in with technology providers could impact long-term costs
#
# ## Risk Mitigation Recommendations
#
# 1. **Phased Implementation Approach**:
#    - Begin with limited functionality to validate technical assumptions
#    - Implement in non-critical customer segments before full deployment
#
# 2. **Compliance Framework Development**:
#    - Conduct formal privacy impact assessment before development
#    - Establish AI ethics guidelines for customer interactions
#    - Implement robust data governance processes
#
# 3. **Financial Risk Hedging**:
#    - Structure vendor contracts with performance-based metrics
#    - Establish clear exit criteria for project phases to limit financial exposure
#    - Consider partnership models to share development costs
#
# ## Compliance Checklist
# - [ ] Privacy impact assessment
# - [ ] AI ethics and governance framework
# - [ ] Customer data processing consent mechanisms
# - [ ] Transparency documentation for AI decision-making
# - [ ] Data retention and deletion protocols
#
# The projected ROI appears achievable with proper risk management, though I recommend developing detailed contingency plans for the identified risk factors.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Financial Assessment: AI-Powered Customer Service Platform\n\nFrom a financial perspective, this investment presents an attractive opportunity, but I'd recommend further analysis before proceeding.\n\n## Initial Analysis\n- $2M upfront investment\n- 150% projected 3-year ROI implies a $5M return ($3M profit) over the period\n- Simple annual return would average approximately 50% (very strong)\n\n## Key Financial Considerations\n- **Cash Flow Timing**: When will returns begin materializing? Is the ROI back-loaded?\n- **Budget Impact**: How does this affect short-term liquidity and other planned investments?\n- **ROI Calculation Verification**: Were all costs factored in? (ongoing maintenance, training, integration)\n- **Sensitivity Analysis**: How robust is the ROI if adoption is slower or implementation costs increase?\n\n## Recommended Next Steps\n1. Request detailed quarterly cash flow projections\n2. Compare against alternative investments/opportunities\n3. Establish clear financial KPIs for measuring actual performance against projections\n\nWould you like me to explore any specific aspect of this investment in greater detail?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[7.160024881362915], traces=[<strands.telemetry.metrics.Trace object at 0x10fa44890>], accumulated_usage={'inputTokens': 77, 'outputTokens': 245, 'totalTokens': 322}, accumulated_metrics={'latencyMs': 6087}), state={}), execution_time=7160, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 77, 'outputTokens': 245, 'totalTokens': 322}, accumulated_metrics={'latencyMs': 6087}, execution_count=1), 'market_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Market Research Assessment: AI-Powered Customer Service Platform\n\n## Market Landscape Analysis\n\nBased on the financial projections ($2M investment with 150% 3-year ROI), I've conducted a market assessment to validate these expectations against current market conditions.\n\n### Market Trends\n- The AI customer service market is growing at 25-30% annually, indicating strong demand\n- Enterprise adoption of AI for customer service has increased by 45% in the last two years\n- Competitor solutions are showing 30-40% reduction in customer service costs for clients\n\n### Customer Needs Validation\n- Primary customer pain points include:\n  - Rising support costs (particularly staffing)\n  - Increasing customer expectations for 24/7 immediate support\n  - Difficulty scaling human support teams during peak periods\n\n### Competitive Analysis\n- Market has both established players and new entrants\n- Key differentiators driving success include integration capabilities, accuracy of AI responses, and implementation timelines\n- Price points range from $50K-500K annually depending on scale and features\n\n## Financial Projection Assessment\n- The 150% ROI appears achievable but depends heavily on:\n  1. Competitive differentiation strategy\n  2. Sales cycle length (typically 3-9 months in this sector)\n  3. Customer acquisition costs (currently averaging 15-20% of first-year revenue)\n\n## Recommendations\n1. Conduct customer interviews with 3-5 potential early adopters to validate pricing model\n2. Perform competitive feature gap analysis before finalizing development roadmap\n3. Consider a phased rollout strategy to reduce initial investment risk\n\nWould you like me to explore any specific market segment or customer needs in greater detail?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[9.5101797580719], traces=[<strands.telemetry.metrics.Trace object at 0x110822b90>], accumulated_usage={'inputTokens': 335, 'outputTokens': 374, 'totalTokens': 709}, accumulated_metric ...
# =============Node execution order:==========================
# ============================================================
# Executed: finance_expert
# Executed: market_expert
# Executed: tech_expert
# Executed: risk_analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 4
# Completed nodes: 4
# Failed nodes: 0
# Execution time: 32061ms
# Token usage: {'inputTokens': 1623, 'outputTokens': 1542, 'totalTokens': 3165}
# Financial Advisor:
# ============================================================
# ============================================================
# # Financial Assessment: AI-Powered Customer Service Platform
#
# From a financial perspective, this investment presents an attractive opportunity, but I'd recommend further analysis before proceeding.
#
# ## Initial Analysis
# - $2M upfront investment
# - 150% projected 3-year ROI implies a $5M return ($3M profit) over the period
# - Simple annual return would average approximately 50% (very strong)
#
# ## Key Financial Considerations
# - **Cash Flow Timing**: When will returns begin materializing? Is the ROI back-loaded?
# - **Budget Impact**: How does this affect short-term liquidity and other planned investments?
# - **ROI Calculation Verification**: Were all costs factored in? (ongoing maintenance, training, integration)
# - **Sensitivity Analysis**: How robust is the ROI if adoption is slower or implementation costs increase?
#
# ## Recommended Next Steps
# 1. Request detailed quarterly cash flow projections
# 2. Compare against alternative investments/opportunities
# 3. Establish clear financial KPIs for measuring actual performance against projections
#
# Would you like me to explore any specific aspect of this investment in greater detail?
#
#
#
# Technical Expert:
# ============================================================
# ============================================================
# # Technical Architecture Assessment: AI-Powered Customer Service Platform
#
# ## Technical Feasibility Overview
# The proposed AI-powered customer service platform appears technically viable based on current AI capabilities, though successful implementation will depend on several key architectural considerations.
#
# ## Critical Technical Considerations
#
# ### Integration Requirements
# - **Existing Systems Integration**: Will require robust API development to connect with CRM, knowledge bases, ticketing systems, and communication channels
# - **Data Migration Strategy**: Need for clean data transfer from legacy systems without service disruptions
#
# ### Technical Architecture Decisions
# - **Build vs. Buy Assessment**: Evaluate developing proprietary AI models versus leveraging existing solutions (e.g., Azure Bot Service, Google Dialogflow, IBM Watson)
# - **Cloud vs. On-Premise**: Trade-offs between control, security requirements, and scalability needs
# - **Real-time Processing Capabilities**: Architecture must support sub-second response times for customer interactions
#
# ### Implementation Challenges
# - **AI Model Training**: Will require substantial domain-specific data; insufficient training data will impact service quality
# - **Scalability Design**: Must handle variable load patterns with minimal latency
# - **Security Architecture**: Need for comprehensive data protection, particularly for customer information
#
# ## Risk Assessment
# - **Technical Debt**: Rushed implementation to meet ROI timelines could create long-term maintenance issues
# - **Vendor Lock-in**: Depending on platform choices, potential for dependency on specific vendors
# - **Skill Requirements**: Team capabilities assessment needed for AI model maintenance and platform evolution
#
# ## Recommendations
# 1. Conduct technical discovery phase to map integration points and data requirements
# 2. Develop proof-of-concept with subset of functionality to validate technical approach
# 3. Include 15-20% contingency in technical implementation budget for unforeseen challenges
#
# The projected ROI appears achievable from a technical perspective, assuming proper architectural planning and execution.
#
#
#
# Market Researcher:
# ============================================================
# ============================================================
# # Market Research Assessment: AI-Powered Customer Service Platform
#
# ## Market Landscape Analysis
#
# Based on the financial projections ($2M investment with 150% 3-year ROI), I've conducted a market assessment to validate these expectations against current market conditions.
#
# ### Market Trends
# - The AI customer service market is growing at 25-30% annually, indicating strong demand
# - Enterprise adoption of AI for customer service has increased by 45% in the last two years
# - Competitor solutions are showing 30-40% reduction in customer service costs for clients
#
# ### Customer Needs Validation
# - Primary customer pain points include:
#   - Rising support costs (particularly staffing)
#   - Increasing customer expectations for 24/7 immediate support
#   - Difficulty scaling human support teams during peak periods
#
# ### Competitive Analysis
# - Market has both established players and new entrants
# - Key differentiators driving success include integration capabilities, accuracy of AI responses, and implementation timelines
# - Price points range from $50K-500K annually depending on scale and features
#
# ## Financial Projection Assessment
# - The 150% ROI appears achievable but depends heavily on:
#   1. Competitive differentiation strategy
#   2. Sales cycle length (typically 3-9 months in this sector)
#   3. Customer acquisition costs (currently averaging 15-20% of first-year revenue)
#
# ## Recommendations
# 1. Conduct customer interviews with 3-5 potential early adopters to validate pricing model
# 2. Perform competitive feature gap analysis before finalizing development roadmap
# 3. Consider a phased rollout strategy to reduce initial investment risk
#
# Would you like me to explore any specific market segment or customer needs in greater detail?

# %% [markdown]
# ### Branching with conditions
#
# Let's create an agent graph that would classify the request and depending on conditions we define in the code - will route the request either to technical or business agent.
#
# Take a close look on differences between the node execution order and number of nodes executed in this graph based on two different prompts.
#
# <div style="text-align:left">
#     <img src="images/conditional.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

classifier = Agent(model=CLAUDE_MODEL_ID, name="classifier", system_prompt="You are an agent responsible for classification of the report request, return only Technical or Business clasification.")
technical_report = Agent(model=CLAUDE_MODEL_ID, name="technical_expert", system_prompt="You are a technical expert htat focuses on providing short summary from technical perspective")
business_report = Agent(model=CLAUDE_MODEL_ID, name="business_expert", system_prompt="You are a business expert that focuses on providing short summary from business perspective")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(classifier, "classifier")
builder.add_node(technical_report, "technical_report")
builder.add_node(business_report, "business_report")

def is_technical(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "technical" in result_text.lower()

def is_business(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "business" in result_text.lower()

# Add edges (dependencies)
builder.add_edge("classifier", "technical_report", condition=is_technical)
builder.add_edge("classifier", "business_report", condition=is_business)

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("classifier")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Provide report on technical aspect of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

#Execute task on newly built graph
result = graph("Provide report on business impact of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# Technical# Technical Aspects of Working From Home
#
# ## Key Technical Considerations
#
# 1. **Network Infrastructure**
#    - Home internet bandwidth requirements (minimum 25 Mbps download/5 Mbps upload recommended)
#    - Router quality and Wi-Fi coverage throughout workspace
#    - Wired connections for stability during critical tasks
#
# 2. **Hardware Requirements**
#    - Appropriate computing devices (laptop/desktop with sufficient processing power)
#    - Secondary display setup for productivity
#    - Peripheral requirements (webcam, headset, keyboard, mouse)
#
# 3. **Software & Collaboration Tools**
#    - VPN configurations for secure network access
#    - Video conferencing platforms (Zoom, Teams, etc.)
#    - Project management and collaboration software
#
# 4. **Remote Access Solutions**
#    - Remote desktop protocols
#    - Cloud-based workspace environments
#    - File sharing and synchronization methods
#
# ## Key Risk Factors
#
# 1. **Security Vulnerabilities**
#    - Unsecured home networks exposing corporate data
#    - Personal device use without proper endpoint protection
#    - Inadequate authentication mechanisms
#
# 2. **Technical Reliability Issues**
#    - Internet service provider outages
#    - Hardware failures without immediate IT support
#    - Power instability affecting equipment and productivity
#
# 3. **System Performance Limitations**
#    - Bandwidth contention with household members
#    - VPN connection stability and latency problems
#    - Resource-intensive applications struggling on home equipment
#
# 4. **Data Management Risks**
#    - Local storage of sensitive information
#    - Backup failures due to network limitations
#    - Data synchronization conflicts between systems
#
# This technical assessment provides the foundation for establishing a secure, reliable, and productive remote work environment.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.712231159210205], traces=[<strands.telemetry.metrics.Trace object at 0x10faa5c10>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 717}), state={}), execution_time=1712, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 717}, execution_count=1), 'technical_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Technical Aspects of Working From Home\n\n## Key Technical Considerations\n\n1. **Network Infrastructure**\n   - Home internet bandwidth requirements (minimum 25 Mbps download/5 Mbps upload recommended)\n   - Router quality and Wi-Fi coverage throughout workspace\n   - Wired connections for stability during critical tasks\n\n2. **Hardware Requirements**\n   - Appropriate computing devices (laptop/desktop with sufficient processing power)\n   - Secondary display setup for productivity\n   - Peripheral requirements (webcam, headset, keyboard, mouse)\n\n3. **Software & Collaboration Tools**\n   - VPN configurations for secure network access\n   - Video conferencing platforms (Zoom, Teams, etc.)\n   - Project management and collaboration software\n\n4. **Remote Access Solutions**\n   - Remote desktop protocols\n   - Cloud-based workspace environments\n   - File sharing and synchronization methods\n\n## Key Risk Factors\n\n1. **Security Vulnerabilities**\n   - Unsecured home networks exposing corporate data\n   - Personal device use without proper endpoint protection\n   - Inadequate authentication mechanisms\n\n2. **Technical Reliability Issues**\n   - Internet service provider outages\n   - Hardware failures without immediate IT support\n   - Power instability affecting equipment and productivity\n\n3. **System Performance Limitations**\n   - Bandwidth contention with household members\n   - VPN connection stability and latency problems\n   - Resource-intensive applications struggling on home equipment\n\n4. **Data Management Risks**\n   - Local storage of sensitive information\n   - Backup failures due to network limitations\n   - Data synchronization conflicts between systems\n\nThis technical assessment provides the foundation for establishing a secure, reliable, and productive remote work environment.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[9.224855899810791], traces=[<strands.telemetry.metrics.Trace object at 0x10b43a1d0>], accumulated_usage={'inputTokens': 60, 'outputTokens': 374, 'totalTokens': 434}, accumulated_metrics={'latencyMs': 8325}), state={}), execution_time=9225, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 60, 'outputTokens': 374, 'totalTokens': 434}, accumulated_metrics={'latencyMs': 8325}, execution_count=1)}, accumulated_usage={'inputTokens': 106, 'outputTokens': 378, 'totalTokens': 484}, accumulated_metrics={'latencyMs': 9042}, execution_count=2, execution_time=10938, total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x10e1cae90>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.712231159210205], traces=[<strands.telemetry.metrics.Trace object at 0x10faa5c10>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 717}), state={}), execution_time=1712, status=<Status ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: technical_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 10938ms
# Token usage: {'inputTokens': 106, 'outputTokens': 378, 'totalTokens': 484}
# Classifier:
# ============================================================
# ============================================================
# Technical
#
#
#
# Business# Business Impact of Working from Home: Summary
#
# ## Key Business Considerations
#
# 1. **Cost savings opportunities**
#    - Reduced real estate expenses and office overhead
#    - Decreased commuting reimbursements
#    - Potential for global talent acquisition without relocation costs
#
# 2. **Productivity implications**
#    - Mixed evidence on productivity impacts
#    - Potential for increased focus without office distractions
#    - Extended working hours with saved commute time
#
# 3. **Technology requirements**
#    - Infrastructure investment for remote collaboration
#    - Cybersecurity enhancements
#    - Digital workflow adaptation
#
# 4. **Employee experience**
#    - Improved work-life balance
#    - Potential for reduced turnover
#    - Changed company culture dynamics
#
# ## Primary Risk Factors
#
# 1. **Communication challenges**
#    - Reduced spontaneous collaboration
#    - Potential siloing of teams and knowledge
#    - Meeting fatigue and digital communication overload
#
# 2. **Management concerns**
#    - Performance monitoring complexity
#    - Maintaining engagement and motivation remotely
#    - Ensuring equitable opportunities and visibility
#
# 3. **Compliance issues**
#    - Tax implications for cross-jurisdiction workers
#    - Labor law variations by location
#    - Data security and privacy regulations
#
# 4. **Culture and innovation risks**
#    - Diminished social connections between employees
#    - Potential impact on creativity and innovation
#    - Onboarding and mentoring challenges for new hires
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.712231159210205, 0.6416549682617188], traces=[<strands.telemetry.metrics.Trace object at 0x10faa5c10>, <strands.telemetry.metrics.Trace object at 0x1107eb650>], accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 1280}), state={}), execution_time=642, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 1280}, execution_count=1), 'business_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Business Impact of Working from Home: Summary\n\n## Key Business Considerations\n\n1. **Cost savings opportunities**\n   - Reduced real estate expenses and office overhead\n   - Decreased commuting reimbursements\n   - Potential for global talent acquisition without relocation costs\n\n2. **Productivity implications**\n   - Mixed evidence on productivity impacts\n   - Potential for increased focus without office distractions\n   - Extended working hours with saved commute time\n\n3. **Technology requirements**\n   - Infrastructure investment for remote collaboration\n   - Cybersecurity enhancements\n   - Digital workflow adaptation\n\n4. **Employee experience**\n   - Improved work-life balance\n   - Potential for reduced turnover\n   - Changed company culture dynamics\n\n## Primary Risk Factors\n\n1. **Communication challenges**\n   - Reduced spontaneous collaboration\n   - Potential siloing of teams and knowledge\n   - Meeting fatigue and digital communication overload\n\n2. **Management concerns**\n   - Performance monitoring complexity\n   - Maintaining engagement and motivation remotely\n   - Ensuring equitable opportunities and visibility\n\n3. **Compliance issues**\n   - Tax implications for cross-jurisdiction workers\n   - Labor law variations by location\n   - Data security and privacy regulations\n\n4. **Culture and innovation risks**\n   - Diminished social connections between employees\n   - Potential impact on creativity and innovation\n   - Onboarding and mentoring challenges for new hires'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[10.086944103240967], traces=[<strands.telemetry.metrics.Trace object at 0x112847910>], accumulated_usage={'inputTokens': 59, 'outputTokens': 318, 'totalTokens': 377}, accumulated_metrics={'latencyMs': 9112}), state={}), execution_time=10087, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 59, 'outputTokens': 318, 'totalTokens': 377}, accumulated_metrics={'latencyMs': 9112}, execution_count=1)}, accumulated_usage={'inputTokens': 177, 'outputTokens': 326, 'totalTokens': 503}, accumulated_metrics={'latencyMs': 10392}, execution_count=2, execution_time=10730, total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x10e1cae90>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.712231159210205, 0.6416549682617188], traces=[<strands.telemetry.metrics.Trace object at 0x10faa5c10>, <strands.telemetry.metrics.Trace object at 0x1107eb650>], accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 1280}), state={}), execution_time=642, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 1280}, ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: business_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 10730ms
# Token usage: {'inputTokens': 177, 'outputTokens': 326, 'totalTokens': 503}
# Classifier:
# ============================================================
# ============================================================
# Business

# %% [markdown]
# ## Key Takeaways and Best Practices
#
#
# ### Best Practices:
#
# **Design for acyclicity:** Ensure your graph has no cycles</p>
# **Use meaningful node IDs:** Choose descriptive names for nodes</p>
# **Validate graph structure:** The builder will check for cycles and validate entry points</p>
# **Handle node failures:** Consider how failures in one node affect the overall workflow</p>
# **Use conditional edges:** For dynamic workflows based on intermediate results</p>
# **Consider parallelism:** Independent branches can execute concurrently</p>
# **Nest multi-agent patterns:** Use Swarms within Graphs for complex workflows</p>
# **Leverage multi-modal inputs:** Use ContentBlocks for rich inputs including images</p>
#
# ## Conclusion
#
# You've now mastered the fundamentals of building multi-agent systems with Strands Agent Graph! You can create sophisticated networks of specialized AI agents that collaborate to solve complex problems.
#
# The key to successful multi-agent systems is:
# - Matching topology to use case
# - Defining clear agent roles and responsibilities
# - Establishing proper communication patterns
# - Managing resources and cleanup effectively
#
# From here, you can build increasingly sophisticated systems for real-world applications in research, content creation, decision-making, customer service, and beyond.
